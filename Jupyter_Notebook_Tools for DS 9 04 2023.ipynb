# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # IG'S ASSIGNMENT 9/04/2023

# %% [markdown]
# ## THIS IS FOR THE FINAL ASSIGNMENT FOR TOOLS FOR DATA SCIENCE

# %% [markdown]
# #### DATA SCIENCE LANGUAGES:
# 1. Pyton
# 2. R
# 3. SQL
# 4. MATLAB
# 5. Scala
# 6. SAS

# %% [markdown]
# #### DATA SCIENCE LIBRARIES:
#   * NumPy
#   * Pandas
#   * TensorFlow
#   * Keras
#   * PyTorch

# %% [markdown]
# ### Data Science Tools:
# | Open Source      | Commercial       |
# |------------------|-----------------:|
# | Jupiter NoteBopok| Tableau          |
# | Apache Hadoop    | IBM Watson Studio|

# %% [markdown]
# ### Below you can see the example of the simple arithmetic expression:

# %%
45*76+67*5
# Out:
# 3755

# %%
def minutes_to_hours(minutes):
    hours = minutes / 60
    return hours
minutes = 120
hours = minutes_to_hours(minutes)
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 120 minutes is equal to 2.0 hours

# %% [markdown]
# ### Objectives:
#
# - Test Data Science Tools in practice;
# - Complete Assignment;
# -
